# %%
from aopy import datareader, datafilter
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, FactorAnalysis
from sklearn import model_selection
from scipy import signal, stats
from numba import cuda
import time

# Generic Functions
def ima_preprocess(data_in, time_start, time_stop, srate, on, ftype, order, Wn, verbose = True, var_thresh = False):
    '''
    This function preprocesses data before dimensionality reduction by subsampling the data for a given time window.
    This function will return 'None' if the variance is above threshold
    
    Inputs:
        data_in [nchannel, ntime]: Raw data in
        time_start [int]: Time to start analysis (s)
        time_stop [int]: Time to stop analysis (s)
        srate [int]: Sampling rate (hz)
        on [bool]: If filtering is turned on
        ftype [string]: Type of filter (bandpass, lowpass, highpass)
        order [int]: Filter order
        Wn (tuple): Cut off frequencies
        verbose (bool): Display start and stop indices
        var_thresh (int): Maximum variance threshold. 
        
    Output:
        data_out (nchannel, ntime): Subsampled and filtered data
    '''
    
    # Define subsampled time range
    if type(time_start) != int or type(time_stop) != int:
        stidx = (time_start*srate).astype(int)
        spidx = (time_stop*srate).astype(int)
    else:
        stidx = time_start*srate
        spidx = time_stop*srate
    
    # Check that data doesn't contain any artifacts if a max variance value is set
    if type(var_thresh) is int:
        data_in_var = np.var(data_in[:,stidx:spidx])
        if data_in_var > var_thresh:
            return None
        
    # Print start and stop index of the subsample analyzed.
    if verbose == True:
        print('Start Index: ' + str(stidx))
        print('Stop Index: ' + str(spidx))
    data = data_in[:,stidx:spidx]
    
    # Butterworth filter
    if on is True:
        sos = signal.butter(order, Wn, ftype, fs = srate, output = 'sos')
        data_out = signal.sosfiltfilt(sos, data, 1)    
    
    return data_out

def ima_fa(data_in, ncomp_fa, nfold, maxiter, verbose):
    '''
    Apply cross validated factor analysis (FA) to input data. Cross validated scores are averaged across n folds.
    
    Inputs:
        data_in [nchannel, ntime]: Data in
        ncomp_fa [n dimensions]: Array of dimensions to compute FA across 
        nfold [int]: Number of cross validation folds to compute
        maxiter [int]: Maximum number of FA iterations to compute if there is no convergence
        verbose [bool]: Display % of dimensions completed
    Outputs:
        fascore['test_score_mu'] [n dimensions]: Array of MLE FA score for each dimension
        fascore['converge'] [n dimensions]: Indicates if the FA converged before reaching the maximum iteration value.
                0: FA did not converge
                1: FA converged
    '''
    
    # Initialize arrays
    fascore = {'test_scores':  np.zeros((np.max(np.shape(ncomp_fa)), nfold))}
    fascore['test_score_mu'] = np.zeros((np.max(np.shape(ncomp_fa))))
    fascore['converge'] = np.zeros(np.max(np.shape(ncomp_fa)))
    converge = np.zeros((nfold))
    
    # Split data into training and testing sets and perform FA analysis for each dimension
    if verbose == True:
        print('Cross validating and fitting ...')
    
    for jj in range(len(ncomp_fa)):
        ii = 0
        for trainidx, testidx in model_selection.KFold(n_splits = nfold).split(data_in):

            fa = FactorAnalysis(n_components = ncomp_fa[jj], max_iter = maxiter)
            fafit = fa.fit(data_in[trainidx,:])
            fascore['test_scores'][jj,ii] = fafit.score(data_in[testidx,:])
            converge[ii] = fafit.n_iter_
            ii += 1
        
        fascore['test_score_mu'][jj] = np.mean(fascore['test_scores'][jj,:])
        
        # Return flag if the factor analysis doesn't converge
        if max(converge) == maxiter:
            fascore['converge'][jj] = 0
        else:
            fascore['converge'][jj] = 1
        
        if verbose == True:
            print(str((100*(jj+1))//len(ncomp_fa)) + "% Complete")
            
    return fascore

def ima_combine_results(p2l1, p2l2, p2s):
    '''
    Concatenate results from multiple FA result files and save to a file
    
    Input:
        p2l1 [list of strings]: List of file paths to iterate through
        p2l2 [list of strings]: List of file paths to iterate through to combine with p2l2
        p2s [list of strings]: List of file paths to save concatenated arrays to
        
    Output:
        No returned outputs. This function saves the concatenated array for each filepath combination to the corresponding 
        p2s filepath.
    '''
    
    # Check if all lists are the same length
    if len(p2l1) != len(p2l2) != len(p2s):
        raise 
        
    for ii in range(len(p2l1)):
        data1 = np.load(p2l1[ii])
        data2 = np.load(p2l2[ii])

        data_out = np.concatenate((data1, data2), axis = 2)
        np.save(p2s[ii], data_out)
        
def ima_setvarThresh(p2l, var_multiplier):
    '''
    Determine variance threshold by calculating the variance of the entire dataset and multiplying it by a specified number
    
    Input:
        p2l [string]: Path to load raw data set
        var_multiplier [int]: threshold multiplier to determine a variance cutoff
        
    Output:
        thresh [float]: Variance threshold
    '''
    
    # Load data set and determine 3 std 
    data_in, data_param, data_mask = datareader.load_ecog_clfp_data(p2l)
    thresh = var_multiplier*np.var(data_in)
    return thresh

def plot_FAdims(data, state, save_figs, p2s, vmaxin = 20, cblbl = 'Dimensionality', xlbl = 'Trial Number', extent_bnds = None):
    '''
    Plot factor analysis (FA) results as an image across multiple trials
    
    Inputs:
        data [n freq band, ntrials]: FA results across multiple trials
        state [string]: Figure title
        save_figs [bool]: Save figures or not
        p2s [string]: Path to save results
        vmaxin [int]: Max colormap c axis value
        cblbl [string]: Colormap label
        xlbl [string]: X axis lbl
        extent_bnds [xmin, xmax, ymax, ymin]: Range of image shown
        
    Outputs:
        No returned outputs. Shows a figure with dimensionality results across trials and saves to a specified filepath if desired
    '''
    f,ax = plt.subplots(1,1,figsize=(10,4))
    plt.imshow(data, aspect = 'auto', vmin = 0, vmax = vmaxin, extent = extent_bnds)
    cb = plt.colorbar(fraction = 0.03, pad = 0.01)
    cb.ax.set_ylabel(cblbl, fontsize = 24, rotation = 270, labelpad=25)
    cb.ax.tick_params(labelsize=20)
    plt.xlabel(xlbl, fontsize = 24)
    plt.ylabel('Freq Band Number', fontsize = 24)
    plt.xticks(fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.title(state, fontsize = 28)
    if save_figs == True:
        f.savefig(p2s,bbox_inches = "tight", dpi = 300)

def plot_FAhist(data, state, save_figs, p2s):
    '''
    This function plots a histogram showing the distribution of dimensionality for each frequency band given multiple trials
    
    Inputs:
        data [n freq band, ntrials]: FA results across multiple trials
        state [string]: Figure title
        save_figs [bool]: Save figures or not
        p2s [string]: Path to save results
        
    Outputs:
        No returned output. Shows a figure and saves the figure if desired.
    '''
    
    fig = plt.figure(figsize = (10,4))
    plt.title(state, fontsize = 28)
    plt.xlabel('Dimensionality', fontsize = 20)
    plt.ylabel('Count', fontsize = 20)
    plt.xticks(fontsize = 20)
    plt.yticks(fontsize = 20)
    
    for ii in range(data.shape[0]):
        plt.hist(data[ii,:], bins = 5, alpha = 0.5, label=str(ii))

    plt.legend(prop = {'size': 16})
    plt.show()
    if save_figs == True:
        fig.savefig(p2s, bbox_inches = "tight", dpi = 300)
        
def ima_load_FAresults(p2l, minFAdim = 1):
    '''
    Load maximum likelihood estimates from factor analysis (FA) results
    
    Inputs:
        p2l [list of strings]: List of .npy datapath to load FA results
        minFAdim [int]: Minimum FA dimension analyzed
        
    Output:
        fa_out [n freq band, ntrial, npath]: Dimension with maximum likelihood value for each frequency band, trial and path
    '''
    
    # Load first data set to get data shape
    temp = np.load(p2l[0])
    
    # Initialize variables
    fa_out = np.zeros((temp.shape[0], temp.shape[2], len(p2l)))
    
    for ii in range(len(p2l)):
        fa_mle = np.load(p2l[ii])
        fa_out[:,:,ii] = np.argmax(fa_mle, 1) + minFAdim
    
    return fa_out


def ima_ptest(ptest_data):
    '''
    Calculate ptest results comparing all combinations of each frequency band input
    
    Inputs:
        ptest_data [n freq band, ntrials, nstate]: Data set containing the dimensionality for each trial across each
        frequency band and neural state to test
        
    Outputs:
        ptest_results [nstate, nstate, n freq band]: pscore results comparing the neural states for each frequency band
    '''
    
    ptest_results = np.zeros((ptest_data.shape[2], ptest_data.shape[2], ptest_data.shape[0]))
    for ii in range(ptest_data.shape[0]):
        for jj in itertools.combinations_with_replacement([0,1,2,3], 2):
            ttest = stats.ttest_ind(ptest_data[ii,:,jj[1]], ptest_data[ii,:,jj[0]], equal_var = False)
            ptest_results[jj[1], jj[0], ii] = ttest.pvalue
    return ptest_results

# %%
# Plotting functions specific to the tests I ran
def ima_loadFAplot(p2l, p2s, save_figs, minFAdim = 1):
    '''
    Loads save FA results, calculates dimensionality, and plots dimensionality across trials and a histogram of 
    dimensionality distribution across trials. Also prints the mean and standard deviation of dimensionality across
    the trials.
    
    Inputs:
        p2l [string]: File path to load FA results
        p2s [string]: File path to save figures
        save_figs [bool]: Save figures or not
        minFAdim [int]: Starting dimension FA is performed on
        
    Output
        No returned outputs. Creates and saves images and prints average dimensionality and standard deviation.
    '''
    
    fa_mle = np.load(p2l)

    fa_max_mle = np.argmax(fa_mle, 1) + minFAdim

    # Plot dimensionality for asleep data
    plot_FAdims(fa_max_mle, 'Asleep', save_figs, p2s + '.png')

    # Plot Histogram
    plot_FAhist(fa_max_mle, 'Asleep', save_figs, p2s + '_hist.png')

    # Calculate Mean and Std
    sleep_mu = np.mean(fa_max_mle, axis = 1)
    sleep_std = np.std(fa_max_mle, axis = 1)
    print('1-4 Hz Avg/Std Dimensionality: ', round(sleep_mu[0],1), '/', round(sleep_std[0],1))
    print('4-10 Hz Avg/Std Dimensionality: ', round(sleep_mu[1],1), '/', round(sleep_std[1],1))
    print('10-20 Hz Avg/Std Dimensionality: ', round(sleep_mu[2],1), '/', round(sleep_std[2],1))
    print('20-40 Hz Avg/Std Dimensionality: ', round(sleep_mu[3],1), '/', round(sleep_std[3],1))
    print('40-70 Hz Avg/Std Dimensionality: ', round(sleep_mu[4],1), '/', round(sleep_std[4],1))
    print('70-100 Hz Avg/Std Dimensionality: ', round(sleep_mu[5],1), '/', round(sleep_std[5],1))
    print('\n')
    
def ima_plot_cummu(data,fband, titlelbl, p2s,save_figs):
    '''
    This function plots the results of calculating the cumulative average across trials for each predefined state
    
    Inputs:
        data [nfreq band, navged trial, nstate]: Cumulative average data for 50 trials and 4 specific states
        fband [int]: Which frequency band to analyze
        titlelbl [string]: ID to name figure and saved figure. Typically the frequency band analyzed
        p2s [string]: Path to save data
        save_figs [bool]: Save figures or not
        
    Outputs:
        No defined outputs. Creates a figure and saves it
    '''
    fig = plt.figure(figsize = (10,6))
    plt.plot(np.arange(1, 51),data[fband,:,0], label = 'Spont Rec002', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,1], label = 'Spont Rec004', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,2], label = 'VisEP Rec003', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,3], label = 'Task Reck 007', linewidth = 2)
    plt.xlabel('Number of Trials Averaged', fontsize = 18)
    plt.ylabel('Dimensionality', fontsize = 18)
    plt.title(titlelbl, fontsize = 22)
    plt.ylim((0, 8.5))
    plt.legend(bbox_to_anchor=(1, 1), fontsize = 12)
    plt.show()
    if save_figs == True:
        fig.savefig('E:/aolab/codes/ima/python/Results/180325/cummu_'+titlelbl, bbox_inches = "tight", dpi = 300)
        
def ima_plot_cumSTD(data,fband, titlelbl, p2s,save_figs):
    '''
    This function plots the results of calculating the cumulative standard deviation across trials for each predefined state
    
    Inputs:
        data [nfreq band, navged trial, nstate]: Cumulative standard deviation data for 50 trials and 4 specific states
        fband [int]: Which frequency band to analyze
        titlelbl [string]: ID to name figure and saved figure. Typically the frequency band analyzed
        p2s [string]: Path to save data
        save_figs [bool]: Save figures or not
        
    Outputs:
        No defined outputs. Creates a figure and saves it
    '''
    fig = plt.figure(figsize = (10,6))
    plt.plot(np.arange(1, 51),data[fband,:,0], label = 'Spont Rec002', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,1], label = 'Spont Rec004', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,2], label = 'VisEP Rec003', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,3], label = 'Task Reck 007', linewidth = 2)
    plt.xlabel('Number of Trials Averaged', fontsize = 18)
    plt.ylabel('Dimensionality', fontsize = 18)
    plt.title(titlelbl, fontsize = 22)
    plt.ylim((0, 8.5))
    plt.legend(bbox_to_anchor=(1, 1), fontsize = 12)
    plt.show()
    if save_figs == True:
        fig.savefig('E:/aolab/codes/ima/python/Results/180325/cumstd_'+titlelbl, bbox_inches = "tight", dpi = 300)  

def ima_plot_ptest(data, titlelbl, annotate, save_figs, p2s = ''):
    '''
    This function creates an images showing the ptest results and saves the figure
    
    Inputs:
        data [nstate, nstate]: Data with pscores between individual neural states
        titlelbl [string]: ID to name figure and save plot 
        annotate [bool]: To print the pscore for each combination on the figure
        save_figs [bool]: Save figures or not
        p2s [string]: Path to save data
    '''
    
    f,ax = plt.subplots(1,1,figsize=(10,4))
    plt.imshow(data, aspect = 'auto', vmin = 0, vmax = 1)
    cb = plt.colorbar(fraction = 0.03, pad = 0.01)
    cb.ax.set_ylabel('pscore', fontsize = 24, rotation = 270, labelpad=25)
    cb.ax.tick_params(labelsize=20)
    plt.xlabel('Neural state ID', fontsize = 24)
    plt.ylabel('Neural state ID', fontsize = 24)
    plt.xticks(ticks = [0,1, 2, 3], fontsize = 20)
    plt.yticks(ticks = [0,1, 2, 3], fontsize = 20)
    plt.title(titlelbl, fontsize = 28)
    
    # Add labels to each box
    if annotate == True:
        for ii in range(data.shape[0]):
            for jj in range(data.shape[1]):
                t = ax.annotate(str(round(data[ii,jj], 3)), (jj-.175,ii+.1), xycoords = 'data', fontsize = 20, color = 'Gray')
    
    if save_figs == True:
        f.savefig((p2s+titlelbl),bbox_inches = "tight", dpi = 600)
        print((p2s+titlelbl))

# %%
# Full processing wrappers specific to my tests
def fullProcessing(datapath, p2s, iterations, dtime, freq_bands, var_thresh = False, data_limit_time = None, data_limit_chan = None, max_dims = 21):
    '''
    This function is a wrapper to run factor analysis with artifact detection with the option to crop the data set 
    in time or by channels.
    
    Inputs:
        datapath [list of strings]: List of strings to fun FA on 
        p2s [list of strings]: List or strings to save FA data in (.npy)
        iterations [int]: Number of trials to run for each datapath
        dtime [int]: Time length to cut each trial to [s]
        freq_bands [n bands, 2]: numpy array of frequncy bands
        var_thresh [int]: Variance threshold for outlier detection
        data_limit_time [start, stop]: Pre limit data to select trials from in time
        data_limit_chan [nchannelID]: Pre limit data to select trials from the channel indices input
        max_dims [int]: maximum number of dimensions to run FA on
        
    Output:
        fa_mle [n freq bands, ndimension, niterations]: FA log likelihood results for each trial at each frequency band
    '''
    # Initialize dictionary
    proc_param = {'time_start': 0, 'time_stop': 0} 
    fa_param = {'ncomp_fa': np.arange(1, max_dims ,1).astype(int), 'nfold': 4, 'maxiter':50000}

    # Load data
    data_in, data_param, data_mask = datareader.load_ecog_clfp_data(datapath)
    
    # Parse data if necessary
    if data_limit_time is not None:
        data_in = data_in[:,(data_limit_time[0]*data_param['srate']):(data_limit_time[1]*data_param['srate'])]
    if data_limit_chan is not None:
        data_in = data_in[data_limit_chan,:]
    
    print('Raw data shape:', data_in.shape)
    
    # Randomly select time ranges
    time_start_rng = np.zeros(iterations)
    time_start_rng = np.random.randint(1,(data_in.shape[1]-dtime)//data_param['srate'], size=iterations)
    
    # Define time stop range
    time_stop_rng = time_start_rng + dtime #[s]
    
    # Check if there are artifacts
    if type(var_thresh) is int:
        for nn in range(len(time_start_rng)):
            temp_data_var = np.var(data_in[:,(time_start_rng[nn]*data_param['srate']):((time_start_rng[nn]+dtime)*data_param['srate'])])
            while temp_data_var > var_thresh:
                print(temp_data_var)
                time_start_rng[nn] = np.random.randint(1,(data_in.shape[1]-dtime)//data_param['srate'], size=1)
                temp_data_var = np.var(data_in[:,(time_start_rng[nn]*data_param['srate']):((time_start_rng[nn]+dtime)*data_param['srate'])])
    
    # Preallocate data arrays
    fa_mle = np.zeros((freq_bands.shape[0], fa_param['ncomp_fa'].shape[0], len(time_start_rng)))
    fa_niter = np.zeros((fa_mle.shape))

    a = time.time()
    # Process data for each start point
    for jj in range(len(time_start_rng)):
        proc_param['time_start'] = time_start_rng[jj]
        proc_param['time_stop'] = time_stop_rng[jj]

        # Compute factor analysis for each frequency band
        for ii in range(freq_bands.shape[0]):
            print('f band ', ii)
            filt_param = {'on': True, 'order': 4, 'ftype': 'bandpass', 'Wn': freq_bands[ii,:]}

            # Process data for each frequency band
            data_proc = ima_preprocess(data_in, **data_param, **filt_param, **proc_param, verbose = False)

            # Compute FA
            fa_out = ima_fa(data_proc, **fa_param, verbose = False)

            # Store MLE
            fa_mle[ii, :, jj] = fa_out['test_score_mu'][:]
            fa_niter[ii,:,jj] = fa_out['converge'][:]

            # Clear fa_out to save memory
            del fa_out

        print(str(100*(jj+1)/len(time_start_rng)) + '% Done')

    b = time.time()
    np.save(p2s, fa_mle)
    print('total fa processing time: ' + str(round(b-a,2)) + 'seconds')
    return fa_mle


def fullPlot(data, p2s, save_figs, minFAdim =1):   
    '''
    Plot the dimensionality after each state runs
    
    Inputs:
        data [n freq band, n dimensions, ntrials]: FA results from full processing
        p2s [list of strings]: File paths to saves figures
        save_figs [bool]: Save figures or not
        minFAdim [int]: Start of dimensions analyzed
        
    Output:
        No returned output. Saves figures and print the average and standard deviation of the dimensionality.
    '''
    fa_max_mle = np.argmax(data, 1) + minFAdim 
    fa_max_mle.shape

    # Plot Dimensionality
    plot_FAdims(fa_max_mle, 'Dimensionality', save_figs, p2s + '.png')

    # Plot Histogram
    plot_FAhist(fa_max_mle, 'Dimensionality Distribution', save_figs, p2s + 'hist.png')

    # Calculate Mean and Std
    awake_mu = np.mean(fa_max_mle, axis = 1)
    awake_std = np.std(fa_max_mle, axis = 1)
    print('1-4 Hz Avg/Std Dimensionality: ', round(awake_mu[0],1), '/', round(awake_std[0],1))
    print('4-10 Hz Avg/Std Dimensionality: ', round(awake_mu[1],1), '/', round(awake_std[1],1))
    print('10-20 Hz Avg/Std Dimensionality: ', round(awake_mu[2],1), '/', round(awake_std[2],1))
    print('20-40 Hz Avg/Std Dimensionality: ', round(awake_mu[3],1), '/', round(awake_std[3],1))
    print('40-70 Hz Avg/Std Dimensionality: ', round(awake_mu[4],1), '/', round(awake_std[4],1))
    print('70-100 Hz Avg/Std Dimensionality: ', round(awake_mu[5],1), '/', round(awake_std[5],1))

# %%
# Run factor analysis on one frequency band for one dataset

# Path to data
datapath = 'E:/aolab/data/Wireless_ECOG/180325/spont/rec004.LM1_ECOG_3.clfp.dat'
#p2s = 'E:/aolab/codes/ima/python/Results'

# Define processing parameters
proc_param = {'time_start': 50, 'time_stop': 53} # time to analyze[s]
filt_param = {'on': True, 'order': 4, 'ftype': 'bandpass', 'Wn': (1, 4)}          # Filter parameters
pca_param = {'ncomp_pca': 'mle'}         # Number of PCA components to compute
fa_param = {'ncomp_fa': np.arange(1, 10 ,1).astype(int), 'nfold': 4, 'maxiter':10000}

# Load data
data_in, data_param, data_mask = datareader.load_ecog_clfp_data(datapath)

# Preprocess data
data_proc = ima_preprocess(data_in, **data_param, **filt_param, **proc_param, var_thresh = 10000)

# If the result is none, the processing stopped because the specified time window has too high variance
if data_proc is None:
    print('Data may include artifacts, FA aborted')
else:
    a = time.time()
    # Compute FA
    fa_out = ima_fa(data_proc, **fa_param, verbose = True)
    b = time.time()

    print('fa processing time: ' + str(round(b-a,2)) + ' seconds')
    
    
# Plot results from single FA fitting
fa_out 
plt.plot(fa_param['ncomp_fa'], fa_out['test_score_mu'])
plt.xlabel('Dimension')
plt.ylabel('Log Likelihood')
plt.show()
print('Estimated dimensionality:', fa_param['ncomp_fa'][np.argmax(fa_out['test_score_mu'])])
# Out:
# Loading data file:
# Start Index: 50000
# Stop Index: 53000
# Cross validating and fitting ...
# 11% Complete
# 22% Complete
# 33% Complete
# 44% Complete
# 55% Complete
# 66% Complete
# 77% Complete
# 88% Complete
# 100% Complete
# fa processing time: 134.45 seconds
# Estimated dimensionality: 5

# %%
# Calculate dimensionality across different frequency bands
freq_bands = np.zeros((6,2))
freq_bands[0,:] = np.array((1, 4))
freq_bands[1,:] = np.array((4, 10))
freq_bands[2,:] = np.array((10, 20))
freq_bands[3,:] = np.array((20, 40))
freq_bands[4,:] = np.array((40, 70))
freq_bands[5,:] = np.array((70, 100))
fa_mle = np.zeros((1, freq_bands.shape[0]))

proc_param = {'time_start': 50, 'time_stop': 53} # time to analyze[s]
fa_param = {'ncomp_fa': np.arange(1, 5, 1).astype(int), 'nfold':4, 'maxiter':10000}
fa_mle = np.zeros((freq_bands.shape[0], fa_param['ncomp_fa'].shape[0]))

# Load data
data_in, data_param, data_mask = datareader.load_ecog_clfp_data(datapath)

a = time.time()
# Compute factor analysis for each frequency band
for ii in range(freq_bands.shape[0]):
    print('f band ', ii)
    filt_param = {'on': True, 'order': 4, 'ftype': 'bandpass', 'Wn': freq_bands[ii,:]}

    # Process data for each frequency band
    data_proc = ima_preprocess(data_in, **data_param, **filt_param, **proc_param, verbose = False)

    # Compute FA
    fa_out = ima_fa(data_proc, **fa_param, verbose = True)

    # Store MLE
    fa_mle[ii, :] = fa_out['test_score_mu']

    # Clear fa_out to save memory
    del fa_out

b = time.time()
print('total fa processing time: ' + str(round(b-a,2)) + 'seconds')

# Normalize
fa_norm = np.zeros((fa_mle.shape))
for ii in range(fa_mle.shape[0]):
    fa_norm[ii,:] = (fa_mle[ii,:] - np.min(fa_mle[ii,:]))/np.max(fa_mle[ii,:] - np.min(fa_mle[ii,:]))
    
# Plot 
dim_axis = np.arange(np.min(fa_param['ncomp_fa']),np.min(fa_param['ncomp_fa'])+fa_norm.shape[1])   
fig = plt.figure(figsize = (10,6))
plt.plot(dim_axis, fa_norm[0,:], label = '1-4 Hz')
plt.plot(dim_axis, fa_norm[1,:], label = '4-10 Hz')
plt.plot(dim_axis, fa_norm[2,:], label = '10-20 Hz')
plt.plot(dim_axis, fa_norm[3,:], label = '20-40 Hz')
plt.plot(dim_axis, fa_norm[4,:], label = '40-70 Hz')
plt.plot(dim_axis, fa_norm[5,:], label = '70-100 Hz')
plt.xlabel('Dimension', fontsize = 14)
plt.ylabel('Normalized Log Likelihood', fontsize = 14)
plt.title('Dimensionality Log Likelihood Across Frequency Bands ', fontsize = 18)
plt.legend(bbox_to_anchor=(0.45, 0.5), fontsize = 12)
plt.show()

for ii in range(fa_mle.shape[0]):
    print('Estimated dimensionality :', fa_param['ncomp_fa'][np.argmax(fa_mle[ii,:])])
# Out:
# Loading data file:
# f band  0
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# f band  1
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# f band  2
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# f band  3
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# f band  4
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# f band  5
# Cross validating and fitting ...
# 25% Complete
# 50% Complete
# 75% Complete
# 100% Complete
# total fa processing time: 55.14seconds
# Estimated dimensionality : 4
# Estimated dimensionality : 1
# Estimated dimensionality : 2
# Estimated dimensionality : 2
# Estimated dimensionality : 1
# Estimated dimensionality : 1

# %%
# Plot normalized log likelihood functions
fa_mle_load = np.load('E:/aolab/codes/ima/python/Results/180325/famle_rec002spont_dtime5_all.npy')
fa_param = {'ncomp_fa': np.arange(1, 21, 1).astype(int), 'nfold':4, 'maxiter':10000}

# Save parameters
p2s = 'E:/aolab/codes/ima/python/Results/180325'
save_figs = False

# Pick a specifc FA run
fa_mle = fa_mle_load[:,:,0]

# Normalize
fa_norm = np.zeros((fa_mle.shape))
for ii in range(fa_mle.shape[0]):
    fa_norm[ii,:] = (fa_mle[ii,:] - np.min(fa_mle[ii,:]))/np.max(fa_mle[ii,:] - np.min(fa_mle[ii,:]))
    
# Plot 
dim_axis = np.arange(np.min(fa_param['ncomp_fa']),np.min(fa_param['ncomp_fa'])+fa_norm.shape[1])   
fig = plt.figure(figsize = (10,6))
plt.plot(dim_axis, fa_norm[0,:], label = '1-4 Hz')
plt.plot(dim_axis, fa_norm[1,:], label = '4-10 Hz')
plt.plot(dim_axis, fa_norm[2,:], label = '10-20 Hz')
plt.plot(dim_axis, fa_norm[3,:], label = '20-40 Hz')
plt.plot(dim_axis, fa_norm[4,:], label = '40-70 Hz')
plt.plot(dim_axis, fa_norm[5,:], label = '70-100 Hz')
plt.xlabel('Dimension', fontsize = 14)
plt.ylabel('Normalized Log Likelihood', fontsize = 14)
plt.title('Dimensionality Log Likelihood Across Frequency Bands ', fontsize = 18)
plt.legend(bbox_to_anchor=(0.45, 0.5), fontsize = 12)
plt.show()

for ii in range(fa_mle.shape[0]):
    print('Estimated dimensionality :', fa_param['ncomp_fa'][np.argmax(fa_mle[ii,:])])

if save_figs == True:
    fig.savefig(p2s + '/freqband_dimsrec003_Sleep.png', dpi = 300)
# Out:
# <ipython-input-21-fcbfccee97ed>:15: RuntimeWarning: invalid value encountered in subtract
#   fa_norm[ii,:] = (fa_mle[ii,:] - np.min(fa_mle[ii,:]))/np.max(fa_mle[ii,:] - np.min(fa_mle[ii,:]))
# Estimated dimensionality : 3
# Estimated dimensionality : 3
# Estimated dimensionality : 3
# Estimated dimensionality : 1
# Estimated dimensionality : 2
# Estimated dimensionality : 1

# %% [markdown]
# ###

# %%
# Run FA 

# Path to raw data
datapath = [
    'E:/aolab/data/Wireless_ECOG/180325/spont/rec002.LM1_ECOG_3.clfp.dat',
    'E:/aolab/data/Wireless_ECOG/180325/spont/rec004.LM1_ECOG_3.clfp.dat',
    'E:/aolab/data/Wireless_ECOG/180325/task/rec007.LM1_ECOG_3.clfp.dat',
    'E:/aolab/data/Wireless_ECOG/180325/visEP/rec003.LM1_ECOG_3.clfp.dat'
]

# Path to save FA results
p2s = [
    'E:/aolab/codes/ima/python/Results/180325/subsampled62/famle_rec002spont_dtime5_test',
    'E:/aolab/codes/ima/python/Results/180325/subsampled62/famle_rec004spont_dtime5_test',
    'E:/aolab/codes/ima/python/Results/180325/subsampled62/famle_rec007task_dtime5_test',
    'E:/aolab/codes/ima/python/Results/180325/subsampled62/famle_rec003visEP_dtime5_test'
]

# Define frequency bands to analyze
freq_bands = np.zeros((6,2))
freq_bands[0,:] = np.array((1, 4))
freq_bands[1,:] = np.array((4, 10))
freq_bands[2,:] = np.array((10, 20))
freq_bands[3,:] = np.array((20, 40))
freq_bands[4,:] = np.array((40, 70))
freq_bands[5,:] = np.array((70, 100))

itr = 3
dtime = 1
#chanlist = np.random.randint(0,210, size=62)
#t_wake = [0*60, 45*60]
#t_sleep = [49*60, 90*60]

 # Iterate over recording number
for ii in range(len(datapath)):
    fa_mle = fullProcessing(datapath[ii], p2s[ii], iterations = itr, dtime = dtime,freq_bands = freq_bands, var_thresh = ima_setvarThresh(datapath[ii], 3), data_limit_time = None, data_limit_chan = None)
    fullPlot(fa_mle, p2s[ii], save_figs = True)

'''
# Iterate over dtime
dtime = [5, 5, 5, 5]
for ii in range(len(dtime)):
    fa_mle = fullProcessing(datapath[0], p2s[ii], iterations = itr, dtime = dtime, var_thresh = 5000)
    fullPlot(fa_mle, p2s[ii], save_figs = True)
'''
# Out:
# Loading data file:
# Loading data file:
# Raw data shape: (211, 294554)
# f band  0
# f band  1
# f band  2
# f band  3
# f band  4
# f band  5
# 33.333333333333336% Done
# f band  0
# f band  1
# f band  2
# f band  3
# f band  4
# f band  5
# 66.66666666666667% Done
# f band  0
# f band  1
# f band  2
# f band  3
# f band  4
# f band  5
# 100.0% Done
# total fa processing time: 1165.25seconds
# 1-4 Hz Avg/Std Dimensionality:  17.0 / 1.4
# 4-10 Hz Avg/Std Dimensionality:  19.0 / 0.8
# 10-20 Hz Avg/Std Dimensionality:  9.0 / 5.1
# 20-40 Hz Avg/Std Dimensionality:  3.0 / 0.8
# 40-70 Hz Avg/Std Dimensionality:  2.3 / 0.5
# 70-100 Hz Avg/Std Dimensionality:  1.0 / 0.0
# Loading data file:
# Loading data file:
# Raw data shape: (211, 410650)
# f band  0
# f band  1
# f band  2
# f band  3
# f band  4
# f band  5
# 33.333333333333336% Done
# f band  0
# f band  1
# f band  2
# f band  3
# f band  4
# f band  5
# 66.66666666666667% Done
# f band  0
# f band  1
# f band  2
# f band  3
# ...

# %%
# Load saved FA data and create plots
# Path to load
p2l = 'E:/aolab/codes/ima/python/Results/180325/subsampled62/famle_rec002spont_dtime5_test.npy'
# Path to save
p2s = 'E:/aolab/codes/ima/python/Results'
# Save figures?
save_figs = False

ima_loadFAplot(p2l, p2s, save_figs)
# Out:
# 1-4 Hz Avg/Std Dimensionality:  17.0 / 1.4
# 4-10 Hz Avg/Std Dimensionality:  19.0 / 0.8
# 10-20 Hz Avg/Std Dimensionality:  9.0 / 5.1
# 20-40 Hz Avg/Std Dimensionality:  3.0 / 0.8
# 40-70 Hz Avg/Std Dimensionality:  2.3 / 0.5
# 70-100 Hz Avg/Std Dimensionality:  1.0 / 0.0

# %%
# Concatenate arrays between saved data
# Path to load 1
p2l = [
    "E:/aolab/codes/ima/python/Results/180325/famle_rec002spont_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec004spont_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec003visEP_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec007task_dtime5_all.npy"
]
# Path to load 2
p2l2 = [
    "E:/aolab/codes/ima/python/Results/180325/famle_rec002spont_dtime5_a6.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec004spont_dtime5_a6.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec003visEP_dtime5_a6.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec007task_dtime5_a6.npy"
]
# Path to save combined array
p2s = [
    "E:/aolab/codes/ima/python/Results/180325/famle_rec002spont_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec004spont_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec003visEP_dtime5_all.npy",
    "E:/aolab/codes/ima/python/Results/180325/famle_rec007task_dtime5_all.npy"
]

ima_combine_results(p2l, p2l2, p2s)

# %%
# Load FA results from .npy files and average
p2l_base = "E:/aolab/codes/ima/python/Results/180325/"
p2l = [
    "famle_rec002spont_dtime5_all.npy",
    "famle_rec004spont_dtime5_all.npy",
    "famle_rec003visEP_dtime5_all.npy",
    "famle_rec007task_dtime5_all.npy"
]

p2l = [p2l_base + p2lidx for p2lidx in p2l]


# Load and average FA results
faout_180325 = ima_load_FAresults(p2l)

# Average results within each recording
spont2_mu = np.mean(faout_180325[:,:,0], axis = 1)
spont4_mu = np.mean(faout_180325[:,:,1], axis = 1)
visEP3_mu = np.mean(faout_180325[:,:,2], axis = 1)
task7_mu = np.mean(faout_180325[:,:,3], axis = 1)
spont2_std = np.std(faout_180325[:,:,0], axis = 1)
spont4_std = np.std(faout_180325[:,:,1], axis = 1)
visEP3_std = np.std(faout_180325[:,:,2], axis = 1)
task7_std = np.std(faout_180325[:,:,3], axis = 1)

# Print results
print('Spont Rec002 1-4 Hz Avg/Std Dimensionality: ', round(spont2_mu[0],1), '/', round(spont2_std[0],1))
print('Spont Rec002 4-10 Hz Avg/Std Dimensionality: ', round(spont2_mu[1],1), '/', round(spont2_std[1],1))
print('Spont Rec002 10-20 Hz Avg/Std Dimensionality: ', round(spont2_mu[2],1), '/', round(spont2_std[2],1))
print('Spont Rec002 20-40 Hz Avg/Std Dimensionality: ', round(spont2_mu[3],1), '/', round(spont2_std[3],1))
print('Spont Rec002 40-70 Hz Avg/Std Dimensionality: ', round(spont2_mu[4],1), '/', round(spont2_std[4],1))
print('Spont Rec002 70-100 Hz Avg/Std Dimensionality: ', round(spont2_mu[5],1), '/', round(spont2_std[5],1))
print('\n')
print('Spont Rec004 1-4 Hz Avg/Std Dimensionality: ', round(spont4_mu[0],1), '/', round(spont4_std[0],1))
print('Spont Rec004 4-10 Hz Avg/Std Dimensionality: ', round(spont4_mu[1],1), '/', round(spont4_std[1],1))
print('Spont Rec004 10-20 Hz Avg/Std Dimensionality: ', round(spont4_mu[2],1), '/', round(spont4_std[2],1))
print('Spont Rec004 20-40 Hz Avg/Std Dimensionality: ', round(spont4_mu[3],1), '/', round(spont4_std[3],1))
print('Spont Rec004 40-70 Hz Avg/Std Dimensionality: ', round(spont4_mu[4],1), '/', round(spont4_std[4],1))
print('Spont Rec004 70-100 Hz Avg/Std Dimensionality: ', round(spont4_mu[5],1), '/', round(spont4_std[5],1))
print('\n')
print('VisEP Rec003 1-4 Hz Avg/Std Dimensionality: ', round(visEP3_mu[0],1), '/', round(visEP3_std[0],1))
print('VisEP Rec003 4-10 Hz Avg/Std Dimensionality: ', round(visEP3_mu[1],1), '/', round(visEP3_std[1],1))
print('VisEP Rec003 10-20 Hz Avg/Std Dimensionality: ', round(visEP3_mu[2],1), '/', round(visEP3_std[2],1))
print('VisEP Rec003 20-40 Hz Avg/Std Dimensionality: ', round(visEP3_mu[3],1), '/', round(visEP3_std[3],1))
print('VisEP Rec003 40-70 Hz Avg/Std Dimensionality: ', round(visEP3_mu[4],1), '/', round(visEP3_std[4],1))
print('VisEP Rec003 70-100 Hz Avg/Std Dimensionality: ', round(visEP3_mu[5],1), '/', round(visEP3_std[5],1))
print('\n')
print('Task Rec007 1-4 Hz Avg/Std Dimensionality: ', round(task7_mu[0],1), '/', round(task7_std[0],1))
print('Task Rec007 4-10 Hz Avg/Std Dimensionality: ', round(task7_mu[1],1), '/', round(task7_std[1],1))
print('Task Rec007 10-20 Hz Avg/Std Dimensionality: ', round(task7_mu[2],1), '/', round(task7_std[2],1))
print('Task Rec007 20-40 Hz Avg/Std Dimensionality: ', round(task7_mu[3],1), '/', round(task7_std[3],1))
print('Task Rec007 40-70 Hz Avg/Std Dimensionality: ', round(task7_mu[4],1), '/', round(task7_std[4],1))
print('Task Rec007 70-100 Hz Avg/Std Dimensionality: ', round(task7_mu[5],1), '/', round(task7_std[5],1))
print('\n')

# Plot
save_figs = False
fig = plt.figure(figsize = (10,6))
plt.plot(spont2_mu, label = 'Spont Rec002')
plt.plot(spont4_mu, label = 'Spont Rec004')
plt.plot(visEP3_mu, label = 'VisEP Rec003')
plt.plot(task7_mu, label = 'Task Reck 007')
plt.xlabel('Frequency Band', fontsize = 14)
plt.ylabel('Dimensionality', fontsize = 14)
plt.title('Average Dimensionality (50 Trials)', fontsize = 18)
plt.legend(bbox_to_anchor=(1, 1), fontsize = 12)
plt.show()
if save_figs == True:
    fig.savefig('E:/aolab/codes/ima/python/Results/180325/TaskDep_dtime4', bbox_inches = "tight", dpi = 300)
# Out:
# Spont Rec002 1-4 Hz Avg/Std Dimensionality:  7.5 / 4.1
# Spont Rec002 4-10 Hz Avg/Std Dimensionality:  3.1 / 1.2
# Spont Rec002 10-20 Hz Avg/Std Dimensionality:  2.8 / 0.6
# Spont Rec002 20-40 Hz Avg/Std Dimensionality:  1.9 / 0.9
# Spont Rec002 40-70 Hz Avg/Std Dimensionality:  1.9 / 0.4
# Spont Rec002 70-100 Hz Avg/Std Dimensionality:  1.0 / 0.0
#
#
# Spont Rec004 1-4 Hz Avg/Std Dimensionality:  5.0 / 4.6
# Spont Rec004 4-10 Hz Avg/Std Dimensionality:  2.4 / 1.3
# Spont Rec004 10-20 Hz Avg/Std Dimensionality:  2.2 / 0.9
# Spont Rec004 20-40 Hz Avg/Std Dimensionality:  1.6 / 0.6
# Spont Rec004 40-70 Hz Avg/Std Dimensionality:  1.3 / 0.5
# Spont Rec004 70-100 Hz Avg/Std Dimensionality:  1.0 / 0.0
#
#
# VisEP Rec003 1-4 Hz Avg/Std Dimensionality:  2.4 / 2.1
# VisEP Rec003 4-10 Hz Avg/Std Dimensionality:  2.0 / 1.2
# VisEP Rec003 10-20 Hz Avg/Std Dimensionality:  2.3 / 1.2
# VisEP Rec003 20-40 Hz Avg/Std Dimensionality:  1.2 / 0.5
# ...

# %%
# Calculate cumulative average STD as trials increase
cummu = np.zeros((faout_180325.shape))
cumSTD = np.zeros((faout_180325.shape))
for ii in range(1, faout_180325.shape[1]+1):
    cummu[:,ii-1,:] = np.mean(faout_180325[:,0:ii,:], axis = 1)
    cumSTD[:,ii-1,:] = np.std(faout_180325[:,0:ii,:], axis = 1)
    
p2s = 'E:/aolab/codes/ima/python/Results/180325/'
save_figs = True

ima_plot_cummu(cummu, 0, 'Average 1-4Hz', p2s, save_figs = save_figs)
ima_plot_cummu(cummu, 1, 'Average 4-10Hz', p2s, save_figs = save_figs)
ima_plot_cummu(cummu, 2, 'Average 10-20Hz', p2s, save_figs = save_figs)
ima_plot_cummu(cummu, 3, 'Average 20-40Hz', p2s, save_figs = save_figs)
ima_plot_cummu(cummu, 4, 'Average 40-70Hz', p2s, save_figs = save_figs)
ima_plot_cummu(cummu, 5, 'Average 70-100Hz', p2s, save_figs = save_figs)

ima_plot_cumSTD(cumSTD, 0, 'STD 1-4Hz', p2s, save_figs = save_figs)
ima_plot_cumSTD(cumSTD, 1, 'STD 4-10Hz', p2s, save_figs = save_figs)
ima_plot_cumSTD(cumSTD, 2, 'STD 10-20Hz', p2s, save_figs = save_figs)
ima_plot_cumSTD(cumSTD, 3, 'STD 20-40Hz', p2s, save_figs = save_figs)
ima_plot_cumSTD(cumSTD, 4, 'STD 40-70Hz', p2s, save_figs = save_figs)
ima_plot_cumSTD(cumSTD, 5, 'STD 70-100Hz', p2s, save_figs = save_figs)

# %%
# Create image showing p-test results between different frequency bands and neural states
import itertools

p2s = 'E:/aolab/codes/ima/python/Results/180325/'
        
save_figs = False
annotate = True

ptest_results = ima_ptest(faout_180325)

ima_plot_ptest(ptest_results[:,:,0], '1-4 Hz ptest', annotate, save_figs, p2s)
ima_plot_ptest(ptest_results[:,:,1], '4-10 Hz ptest', annotate, save_figs, p2s)
ima_plot_ptest(ptest_results[:,:,2], '10-20 Hz ptest', annotate, save_figs, p2s)
ima_plot_ptest(ptest_results[:,:,3], '20-40 Hz ptest', annotate, save_figs, p2s)
ima_plot_ptest(ptest_results[:,:,4], '40-70 Hz ptest', annotate, save_figs, p2s)
ima_plot_ptest(ptest_results[:,:,5], '70-100 Hz ptest', annotate, save_figs,p2s)

# %%
# Calculate p score across number of trials averaged.
ptest_data_out = np.zeros((faout_180325.shape[2], faout_180325.shape[2], faout_180325.shape[0], faout_180325.shape[1]-1))
for mm in range(2,faout_180325.shape[1]):
    ptest_data = faout_180325[:,:mm,:]
    ptest_data_out[:,:,:,mm-1] = ima_ptest(ptest_data)

    
save_figs = False
p2s = 'E:/aolab/codes/ima/python/Results/180325/pscoreXtrial_'
def plot_pscoreXtrials(freqBand, plotTitle, p2s, medFilt_kern = 1):
    fig = plt.figure(figsize = (10,6))    
    for jj in itertools.combinations([0,1,2,3], 2):
        plt.plot(signal.medfilt(ptest_data_out[jj[1],jj[0],freqBand,:], medFilt_kern), linewidth = 2, label = str(jj[1]) + '-' + str(jj[0]))
    plt.xlabel('Trials Averaged', fontsize = 20)
    plt.ylabel('Pscore', fontsize = 20)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.title(plotTitle + ' - MedFilt Kernal Size ' + str(medFilt_kern), fontsize = 24)
    plt.legend(bbox_to_anchor=(1., 1), fontsize = 18)
    plt.show()
    if save_figs == True:
        fig.savefig(p2s+plotTitle+ '_medfilt'+str(medFilt_kern), bbox_inches = "tight", dpi = 300)
        
plot_pscoreXtrials(0, '1-4 Hz', p2s, 1)
plot_pscoreXtrials(1, '4-10 Hz', p2s, 1)
plot_pscoreXtrials(2, '10-20 Hz', p2s, 1)
plot_pscoreXtrials(3, '20-40 Hz', p2s, 1)
plot_pscoreXtrials(4, '40-70 Hz', p2s, 1)

# %%
# Load and process data to show change in dimensionality according to time series length
p2l_base = "E:/aolab/codes/ima/python/Results/180325/Week 1/"
p2l = [
    "famle_rec002spont_dtime1.npy",
    "famle_rec002spont_dtime2.npy",
    "famle_rec002spont_dtime3.npy",
    "famle_rec002spont_dtime4.npy",
    "famle_rec002spont_dtime5.npy",
    "famle_rec002spont_dtime6.npy",
    "famle_rec002spont_dtime7.npy",
    "famle_rec002spont_dtime8.npy",
    "famle_rec002spont_dtime9.npy",
    "famle_rec002spont_dtime10.npy",
    "famle_rec002spont_dtime11.npy",
]

p2l = [p2l_base + p2lidx for p2lidx in p2l]
p2s = 'E:/aolab/codes/ima/python/Results/180325/dtime_test'
save_figs = False

# Load and average FA results
faout_dtime = np.mean(ima_load_FAresults(p2l), axis = 1)
faout_dtime_std = np.std(ima_load_FAresults(p2l), axis = 1)

plot_FAdims(faout_dtime, "Time Series Length Test", save_figs, p2s, xlbl = 'Time Series Length [s]', extent_bnds = [1,12,5,0])
plot_FAdims(faout_dtime_std, "Time Series Length Test STD", save_figs, p2s + '_std', vmaxin = 6, cblbl = 'STD [Dims]', xlbl = 'Time Series Length [s]', extent_bnds = [1,12,5,0])

# Average results within each recording
spont2_mu = np.mean(faout_180325[:,:,0], axis = 1)
spont4_mu = np.mean(faout_180325[:,:,1], axis = 1)
visEP3_mu = np.mean(faout_180325[:,:,2], axis = 1)
task7_mu = np.mean(faout_180325[:,:,3], axis = 1)

# %%
# Load cage sleep vs awake data
p2l_base = "E:/aolab/codes/ima/python/Results/180325/"
p2l = [
    'inCage/famle180325_rec001wireless_wake_dtime5_all.npy',
    'inCage/famle180325_rec001wireless_sleep_dtime5_all.npy',
]

p2l2 = [
    'subsampled62/famle_rec002spontdtime5_sub62_all.npy',
    'subsampled62/famle_rec004spontdtime5_sub62_all.npy',
    'subsampled62/famle_rec007spontdtime5_sub62_all.npy',
    'subsampled62/famle_rec003spontdtime5_sub62_all.npy'
]
p2l = [p2l_base + p2lidx for p2lidx in p2l]
p2l2 = [p2l_base + p2lidx for p2lidx in p2l2]

# Load and average FA results
faout_cage = ima_load_FAresults(p2l)
faout_62 = ima_load_FAresults(p2l2)
print(faout_cage.shape)

# Average results within each recording
wake_mu = np.mean(faout_cage[:,:,0], axis = 1)
sleep_mu = np.mean(faout_cage[:,:,1], axis = 1)
spont2_mu62 = np.mean(faout_62[:,:,0], axis = 1)
spont4_mu62 = np.mean(faout_62[:,:,1], axis = 1)
task7_mu62 = np.mean(faout_62[:,:,2], axis = 1)
visep3_mu62 = np.mean(faout_62[:,:,3], axis = 1)

wake_std = np.std(faout_cage[:,:,0], axis = 1)
sleep_std = np.std(faout_cage[:,:,1], axis = 1)
spont2_std62 = np.std(faout_62[:,:,0], axis = 1)
spont4_std62 = np.std(faout_62[:,:,1], axis = 1)
task7_std62 = np.std(faout_62[:,:,2], axis = 1)
visep3_std62 = np.std(faout_62[:,:,3], axis = 1)

# Print results
print('Wake Rec002 1-4 Hz Avg/Std Dimensionality: ', round(wake_mu[0],1), '/', round(wake_std[0],1))
print('Wake Rec002 4-10 Hz Avg/Std Dimensionality: ', round(wake_mu[1],1), '/', round(wake_std[1],1))
print('Wake Rec002 10-20 Hz Avg/Std Dimensionality: ', round(wake_mu[2],1), '/', round(wake_std[2],1))
print('Wake Rec002 20-40 Hz Avg/Std Dimensionality: ', round(wake_mu[3],1), '/', round(wake_std[3],1))
print('Wake Rec002 40-70 Hz Avg/Std Dimensionality: ', round(wake_mu[4],1), '/', round(wake_std[4],1))
print('Wake Rec002 70-100 Hz Avg/Std Dimensionality: ', round(wake_mu[5],1), '/', round(wake_std[5],1))
print('\n')
print('Spont Rec004 1-4 Hz Avg/Std Dimensionality: ', round(sleep_mu[0],1), '/', round(sleep_std[0],1))
print('Spont Rec004 4-10 Hz Avg/Std Dimensionality: ', round(sleep_mu[1],1), '/', round(sleep_std[1],1))
print('Spont Rec004 10-20 Hz Avg/Std Dimensionality: ', round(sleep_mu[2],1), '/', round(sleep_std[2],1))
print('Spont Rec004 20-40 Hz Avg/Std Dimensionality: ', round(sleep_mu[3],1), '/', round(sleep_std[3],1))
print('Spont Rec004 40-70 Hz Avg/Std Dimensionality: ', round(sleep_mu[4],1), '/', round(sleep_std[4],1))
print('Spont Rec004 70-100 Hz Avg/Std Dimensionality: ', round(sleep_mu[5],1), '/', round(sleep_std[5],1))
print('\n')

# Plot
save_figs = False
plot_all = True

fig = plt.figure(figsize = (10,6))
if plot_all == True:
    plt.plot(spont2_mu, label = 'Spont Rec002', linewidth = 1.5)
    plt.plot(spont4_mu, label = 'Spont Rec004', linewidth = 1.5)
    plt.plot(visEP3_mu, label = 'VisEP Rec003', linewidth = 1.5)
    plt.plot(task7_mu, label = 'Task Reck 007', linewidth = 1.5)
plt.plot(wake_mu, label = 'Wake Rec001', linewidth = 4)
plt.plot(sleep_mu, label = 'Sleep Rec001', linewidth = 4)
plt.xlabel('Frequency Band', fontsize = 18)
plt.ylabel('Dimensionality', fontsize = 18)
plt.title('Average Dimensionality (50 Trials)', fontsize = 22)
plt.legend(bbox_to_anchor=(1, 1), fontsize = 14)
plt.show()
if save_figs == True:
    fig.savefig('E:/aolab/codes/ima/python/Results/180325/WakeSleepChair_Dims', bbox_inches = "tight", dpi = 300)
# Out:
# (6, 50, 2)
# Wake Rec002 1-4 Hz Avg/Std Dimensionality:  8.0 / 5.0
# Wake Rec002 4-10 Hz Avg/Std Dimensionality:  3.6 / 2.1
# Wake Rec002 10-20 Hz Avg/Std Dimensionality:  3.2 / 1.8
# Wake Rec002 20-40 Hz Avg/Std Dimensionality:  3.2 / 1.6
# Wake Rec002 40-70 Hz Avg/Std Dimensionality:  2.5 / 1.0
# Wake Rec002 70-100 Hz Avg/Std Dimensionality:  2.2 / 1.0
#
#
# Spont Rec004 1-4 Hz Avg/Std Dimensionality:  6.6 / 2.9
# Spont Rec004 4-10 Hz Avg/Std Dimensionality:  3.3 / 1.2
# Spont Rec004 10-20 Hz Avg/Std Dimensionality:  2.8 / 0.8
# Spont Rec004 20-40 Hz Avg/Std Dimensionality:  3.0 / 0.4
# Spont Rec004 40-70 Hz Avg/Std Dimensionality:  2.9 / 0.3
# Spont Rec004 70-100 Hz Avg/Std Dimensionality:  2.9 / 0.9

# %%
# Calculate cumulative average STD as trials increase
cummu = np.zeros((faout_cage.shape))
cumSTD = np.zeros((faout_cage.shape))
for ii in range(1, faout_cage.shape[1]+1):
    cummu[:,ii-1,:] = np.mean(faout_cage[:,0:ii,:], axis = 1)
    cumSTD[:,ii-1,:] = np.std(faout_cage[:,0:ii,:], axis = 1)

def plot_cum_cage(data,fband, titlelbl, p2s,save_figs):
    fig = plt.figure(figsize = (10,6))
    plt.plot(np.arange(1, 51),data[fband,:,0], label = 'Wake Rec001', linewidth = 2)
    plt.plot(np.arange(1, 51),data[fband,:,1], label = 'Sleep Rec001', linewidth = 2)
    plt.xlabel('Number of Trials Averaged', fontsize = 18)
    plt.ylabel('Dimensionality', fontsize = 18)
    plt.title(titlelbl, fontsize = 22)
    plt.ylim((0, 8.5))
    plt.legend(fontsize = 14)
    plt.show()
    if save_figs == True:
        fig.savefig('E:/aolab/codes/ima/python/Results/180325/cum_'+titlelbl, bbox_inches = "tight", dpi = 300)
    
p2s = 'E:/aolab/codes/ima/python/Results/180325/'
save_figs = False

plot_cum_cage(cummu, 0, 'Average 1-4Hz', p2s, save_figs = save_figs)
plot_cum_cage(cummu, 1, 'Average 4-10Hz', p2s, save_figs = save_figs)
plot_cum_cage(cummu, 2, 'Average 10-20Hz', p2s, save_figs = save_figs)
plot_cum_cage(cummu, 3, 'Average 20-40Hz', p2s, save_figs = save_figs)
plot_cum_cage(cummu, 4, 'Average 40-70Hz', p2s, save_figs = save_figs)
plot_cum_cage(cummu, 5, 'Average 70-100Hz', p2s, save_figs = save_figs)

plot_cum_cage(cumSTD, 0, 'STD 1-4Hz', p2s, save_figs = save_figs)
plot_cum_cage(cumSTD, 1, 'STD 4-10Hz', p2s, save_figs = save_figs)
plot_cum_cage(cumSTD, 2, 'STD 10-20Hz', p2s, save_figs = save_figs)
plot_cum_cage(cumSTD, 3, 'STD 20-40Hz', p2s, save_figs = save_figs)
plot_cum_cage(cumSTD, 4, 'STD 40-70Hz', p2s, save_figs = save_figs)
plot_cum_cage(cumSTD, 5, 'STD 70-100Hz', p2s, save_figs = save_figs)

# %%
# Compare all cage and chair data
# Create image showing p-test results between different frequency bands and neural states
import itertools

p2s = 'E:/aolab/codes/ima/python/Results/180325/'

def ptest_all(ptest_data):
    ptest_results = np.zeros((ptest_data.shape[2], ptest_data.shape[2], ptest_data.shape[0]))
    for ii in range(ptest_data.shape[0]):
        for jj in itertools.combinations_with_replacement([0,1,2,3,4,5], 2):
            ttest = stats.ttest_ind(ptest_data[ii,:,jj[1]], ptest_data[ii,:,jj[0]], equal_var = False)
            ptest_results[jj[1], jj[0], ii] = ttest.pvalue
    return ptest_results
        

def plot_ptest_all(data, titlelbl, annotate, save_figs, p2s = ''):
    f,ax = plt.subplots(1,1,figsize=(10,4))
    plt.imshow(data, aspect = 'auto', vmin = 0, vmax = 1)
    cb = plt.colorbar(fraction = 0.03, pad = 0.01)
    cb.ax.set_ylabel('pscore', fontsize = 24, rotation = 270, labelpad=25)
    cb.ax.tick_params(labelsize=20)
    plt.xlabel('Neural state ID', fontsize = 24)
    plt.ylabel('Neural state ID', fontsize = 24)
    plt.xticks(ticks = [0,1, 2, 3, 4, 5], fontsize = 20)
    plt.yticks(ticks = [0,1, 2, 3, 4, 5], fontsize = 20)
    plt.title(titlelbl, fontsize = 28)
    
    # Add labels to each box
    if annotate == True:
        for ii in range(data.shape[0]):
            for jj in range(data.shape[1]):
                t = ax.annotate(str(round(data[ii,jj], 3)), (jj-.175,ii+.1), xycoords = 'data', fontsize = 20, color = 'Gray')
    
    if save_figs == True:
        f.savefig((p2s+titlelbl+'_all'),bbox_inches = "tight", dpi = 600)
        print((p2s+titlelbl))
        
save_figs = False
annotate = True

# Concactonate faout_180325 and faout_cage
faout_all = np.concatenate((faout_180325, faout_cage), axis = 2)

ptest_results = ptest_all(faout_all)
plot_ptest_all(ptest_results[:,:,0], '1-4 Hz ptest', annotate, save_figs, p2s)
plot_ptest_all(ptest_results[:,:,1], '4-10 Hz ptest', annotate, save_figs, p2s)
plot_ptest_all(ptest_results[:,:,2], '10-20 Hz ptest', annotate, save_figs, p2s)
plot_ptest_all(ptest_results[:,:,3], '20-40 Hz ptest', annotate, save_figs, p2s)
plot_ptest_all(ptest_results[:,:,4], '40-70 Hz ptest', annotate, save_figs, p2s)
plot_ptest_all(ptest_results[:,:,5], '70-100 Hz ptest', annotate, save_figs,p2s)

# %%
# Calculate p score across number of trials averaged for all data.
ptest_data_out_all = np.zeros((faout_all.shape[2], faout_all.shape[2], faout_all.shape[0], faout_all.shape[1]-1))
for mm in range(2,faout_all.shape[1]):
    ptest_data_all = faout_all[:,:mm,:]
    ptest_data_out_all[:,:,:,mm-1] = ptest_all(ptest_data_all)

    
save_figs = False
p2s = 'E:/aolab/codes/ima/python/Results/180325/pscoreXtrial_'
def plot_pscoreXtrials_all(freqBand, plotTitle, p2s, medFilt_kern = 1):
    fig = plt.figure(figsize = (10,6))    
    for ii in np.arange(4,6):
        for jj in np.arange(0,5):
            if ii != 4 or jj!= 4:
                plt.plot(signal.medfilt(ptest_data_out_all[ii,jj,freqBand,:], medFilt_kern), linewidth = 2, label = str(ii) + '-' + str(jj))
    plt.xlabel('Trials Averaged', fontsize = 20)
    plt.ylabel('Pscore', fontsize = 20)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.title(plotTitle + ' - MedFilt Kernal Size ' + str(medFilt_kern), fontsize = 24)
    plt.legend(bbox_to_anchor=(1., 1), fontsize = 18)
    plt.show()
    if save_figs == True:
        fig.savefig(p2s+plotTitle+ '_medfilt'+str(medFilt_kern)+'_allnew', bbox_inches = "tight", dpi = 300)
        
plot_pscoreXtrials_all(0, '1-4 Hz', p2s, 1)
plot_pscoreXtrials_all(1, '4-10 Hz', p2s, 1)
plot_pscoreXtrials_all(2, '10-20 Hz', p2s, 1)
plot_pscoreXtrials_all(3, '20-40 Hz', p2s, 1)
plot_pscoreXtrials_all(4, '40-70 Hz', p2s, 1)
plot_pscoreXtrials_all(5, '70-100 Hz', p2s, 1)

# %%
for ii in np.arange(4,6):
    print(ii)
# Out:
# 4
# 5

# %%
# Calculate cumulative average STD as trials increase
cummu62 = np.zeros((faout_62.shape))
cumSTD62 = np.zeros((faout_62.shape))
for ii in range(1, faout_62.shape[1]+1):
    cummu62[:,ii-1,:] = np.mean(faout_62[:,0:ii,:], axis = 1)
    cumSTD62[:,ii-1,:] = np.std(faout_62[:,0:ii,:], axis = 1)

def plot_cummu_62(data,fband, titlelbl, p2s,save_figs):
    fig = plt.figure(figsize = (10,6))
    plt.plot(np.arange(1, 54),data[fband,:,0], label = 'Spont Rec002', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,1], label = 'Spont Rec004', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,2], label = 'Task Rec002', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,3], label = 'VisEP Rec004', linewidth = 2)
    plt.xlabel('Number of Trials Averaged', fontsize = 18)
    plt.ylabel('Dimensionality', fontsize = 18)
    plt.title(titlelbl, fontsize = 22)
    plt.ylim((0, 8.5))
    #plt.legend(bbox_to_anchor=(1, 1), fontsize = 12)
    plt.legend(fontsize = 14)
    plt.show()
    if save_figs == True:
        fig.savefig('E:/aolab/codes/ima/python/Results/180325/cummu_'+titlelbl, bbox_inches = "tight", dpi = 300)
        
def plot_cumSTD_62(data,fband, titlelbl, p2s,save_figs):
    fig = plt.figure(figsize = (10,6))
    plt.plot(np.arange(1, 54),data[fband,:,0], label = 'Spont Rec002', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,1], label = 'Spont Rec004', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,2], label = 'Task Rec002', linewidth = 2)
    plt.plot(np.arange(1, 54),data[fband,:,3], label = 'VisEP Rec004', linewidth = 2)
    plt.xlabel('Number of Trials Averaged', fontsize = 18)
    plt.ylabel('Dimensionality', fontsize = 18)
    plt.title(titlelbl, fontsize = 22)
    plt.ylim((0, 8.5))
    #plt.legend(bbox_to_anchor=(1, 1), fontsize = 12)
    plt.legend(fontsize = 14)
    plt.show()
    if save_figs == True:
        fig.savefig('E:/aolab/codes/ima/python/Results/180325/cumstd_'+titlelbl, bbox_inches = "tight", dpi = 300)
    
p2s = 'E:/aolab/codes/ima/python/Results/180325/'
save_figs = False
faout_cage
plot_cummu_62(cummu62, 0, 'Average 1-4Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cummu_62(cummu62, 1, 'Average 4-10Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cummu_62(cummu62, 2, 'Average 10-20Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cummu_62(cummu62, 3, 'Average 20-40Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cummu_62(cummu62, 4, 'Average 40-70Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cummu_62(cummu62, 5, 'Average 70-100Hz - 62 Channels', p2s, save_figs = save_figs)

plot_cumSTD_62(cumSTD62, 0, 'STD 1-4Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cumSTD_62(cumSTD62, 1, 'STD 4-10Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cumSTD_62(cumSTD62, 2, 'STD 10-20Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cumSTD_62(cumSTD62, 3, 'STD 20-40Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cumSTD_62(cumSTD62, 4, 'STD 40-70Hz - 62 Channels', p2s, save_figs = save_figs)
plot_cumSTD_62(cumSTD62, 5, 'STD 70-100Hz - 62 Channels', p2s, save_figs = save_figs)
